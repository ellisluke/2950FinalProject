# %%
import pandas as pd
import numpy as np
import datetime
from datetime import date
import matplotlib.pyplot as plt

# %%
charts = pd.read_csv("Hot Stuff.csv")
vix = pd.read_csv("VIX.csv")

# %%
charts.describe()
# Out:
#        Week Position       Instance  Previous Week Position  Peak Position  \
# count  327895.000000  327895.000000           295941.000000  327895.000000
# mean       50.499309       1.072538               47.604066      41.358307
# std        28.865707       0.334188               28.056915      29.542497
# min         1.000000       1.000000                1.000000       1.000000
# 25%        25.500000       1.000000               23.000000      14.000000
# 50%        50.000000       1.000000               47.000000      39.000000
# 75%        75.000000       1.000000               72.000000      66.000000
# max       100.000000      10.000000              100.000000     100.000000
#
#        Weeks on Chart
# count   327895.000000
# mean         9.153793
# std          7.590281
# min          1.000000
# 25%          4.000000
# 50%          7.000000
# 75%         13.000000
# max         87.000000

# %%
charts.WeekID.min()
# Out:
# '1/1/1966'

# %%
vix.describe()
# Out:
#               Open         High          Low        Close    Adj Close  Volume
# count  8011.000000  8011.000000  8011.000000  8011.000000  8011.000000  8011.0
# mean     19.557959    20.346117    18.820846    19.481100    19.481100     0.0
# std       8.105947     8.562156     7.594262     8.032406     8.032406     0.0
# min       9.010000     9.310000     8.560000     9.140000     9.140000     0.0
# 25%      13.780000    14.395000    13.260000    13.750000    13.750000     0.0
# 50%      17.620001    18.209999    16.969999    17.559999    17.559999     0.0
# 75%      22.959999    23.780000    22.190001    22.840000    22.840000     0.0
# max      82.690002    89.529999    72.760002    82.690002    82.690002     0.0

# %%
charts.shape[0]
# Out:
# 327895

# %%
uniqueSongs = charts.SongID.unique()

# %%
charts.head(20)
# Out:
#                                                   url     WeekID  \
# 0   http://www.billboard.com/charts/hot-100/1965-0...  7/17/1965
# 1   http://www.billboard.com/charts/hot-100/1965-0...  7/24/1965
# 2   http://www.billboard.com/charts/hot-100/1965-0...  7/31/1965
# 3   http://www.billboard.com/charts/hot-100/1965-0...   8/7/1965
# 4   http://www.billboard.com/charts/hot-100/1965-0...  8/14/1965
# 5   http://www.billboard.com/charts/hot-100/1965-0...  8/21/1965
# 6   http://www.billboard.com/charts/hot-100/1965-0...  8/28/1965
# 7   http://www.billboard.com/charts/hot-100/1965-0...   9/4/1965
# 8   http://www.billboard.com/charts/hot-100/1997-0...  4/19/1997
# 9   http://www.billboard.com/charts/hot-100/1997-0...  4/26/1997
# 10  http://www.billboard.com/charts/hot-100/1997-0...   5/3/1997
# 11  http://www.billboard.com/charts/hot-100/1997-0...  5/10/1997
# 12  http://www.billboard.com/charts/hot-100/1997-0...  5/17/1997
# 13  http://www.billboard.com/charts/hot-100/1997-0...  5/24/1997
# 14  http://www.billboard.com/charts/hot-100/1971-0...  4/24/1971
# 15  http://www.billboard.com/charts/hot-100/1971-0...   5/1/1971
# 16  http://www.billboard.com/charts/hot-100/1971-0...   5/8/1971
# 17  http://www.billboard.com/charts/hot-100/1971-0...  5/15/1971
# 18  http://www.billboard.com/charts/hot-100/1971-0...  5/22/1971
# 19  http://www.billboard.com/charts/hot-100/1971-0...  5/29/1971
#
#     Week Position                         Song          Performer  \
# 0              34       Don't Just Stand There         Patty Duke
# 1              22       Don't Just Stand There         Patty Duke
# 2              14       Don't Just Stand There         Patty Duke
# 3              10       Don't Just Stand There         Patty Duke
# 4               8       Don't Just Stand There         Patty Duke
# 5               8       Don't Just Stand There         Patty Duke
# 6              14       Don't Just Stand There         Patty Duke
# 7              36       Don't Just Stand There         Patty Duke
# 8              97   Don't Keep Wasting My Time  Teddy Pendergrass
# 9              90   Don't Keep Wasting My Time  Teddy Pendergrass
# 10             97   Don't Keep Wasting My Time  Teddy Pendergrass
# 11             97   Don't Keep Wasting My Time  Teddy Pendergrass
# 12             93   Don't Keep Wasting My Time  Teddy Pendergrass
# 13             97   Don't Keep Wasting My Time  Teddy Pendergrass
# 14             96  Don't Knock My Love - Pt. 1     Wilson Pickett
# 15             61  Don't Knock My Love - Pt. 1     Wilson Pickett
# 16             41  Don't Knock My Love - Pt. 1     Wilson Pickett
# 17             32  Don't Knock My Love - Pt. 1     Wilson Pickett
# 18             29  Don't Knock My Love - Pt. 1     Wilson Pickett
# 19             22  Don't Knock My Love - Pt. 1     Wilson Pickett
#
#                                          SongID  Instance  \
# 0              Don't Just Stand TherePatty Duke         1
# 1              Don't Just Stand TherePatty Duke         1
# 2              Don't Just Stand TherePatty Duke         1
# 3              Don't Just Stand TherePatty Duke         1
# 4              Don't Just Stand TherePatty Duke         1
# 5              Don't Just Stand TherePatty Duke         1
# 6              Don't Just Stand TherePatty Duke         1
# 7              Don't Just Stand TherePatty Duke         1
# 8   Don't Keep Wasting My TimeTeddy Pendergrass         1
# 9   Don't Keep Wasting My TimeTeddy Pendergrass         1
# 10  Don't Keep Wasting My TimeTeddy Pendergrass         1
# 11  Don't Keep Wasting My TimeTeddy Pendergrass         1
# 12  Don't Keep Wasting My TimeTeddy Pendergrass         1
# 13  Don't Keep Wasting My TimeTeddy Pendergrass         1
# 14    Don't Knock My Love - Pt. 1Wilson Pickett         1
# 15    Don't Knock My Love - Pt. 1Wilson Pickett         1
# 16    Don't Knock My Love - Pt. 1Wilson Pickett         1
# 17    Don't Knock My Love - Pt. 1Wilson Pickett         1
# 18    Don't Knock My Love - Pt. 1Wilson Pickett         1
# 19    Don't Knock My Love - Pt. 1Wilson Pickett         1
#
#     Previous Week Position  Peak Position  Weeks on Chart
# 0                     45.0             34               4
# 1                     34.0             22               5
# 2                     22.0             14               6
# 3                     14.0             10               7
# 4                     10.0              8               8
# 5                      8.0              8               9
# 6                      8.0              8              10
# 7                     14.0              8              11
# 8                      NaN             97               1
# 9                     97.0             90               2
# 10                    90.0             90               3
# 11                    97.0             90               4
# 12                    97.0             90               5
# 13                    93.0             90               6
# 14                     NaN             96               1
# 15                    96.0             61               2
# 16                    61.0             41               3
# 17                    41.0             32               4
# 18                    32.0             29               5
# 19                    29.0             22               6

# %%
charts.columns
# Out:
# Index(['url', 'WeekID', 'Week Position', 'Song', 'Performer', 'SongID',
#        'Instance', 'Previous Week Position', 'Peak Position',
#        'Weeks on Chart'],
#       dtype='object')

# %%
# Convert weekID to python datetime

charts.WeekID = pd.to_datetime(charts.WeekID, errors='ignore', infer_datetime_format=True)

# %%
## new df with only 1990 chart songs and later, sorted by date

start = datetime.datetime(1990, 1, 9)
end = datetime.datetime(2021, 5, 30)

shortChart = charts.loc[charts.WeekID > start]
shortChart.sort_values(by='WeekID')
# Out:
#                                                       url     WeekID  \
# 288514  http://www.billboard.com/charts/hot-100/1990-0... 1990-01-13
# 90453   http://www.billboard.com/charts/hot-100/1990-0... 1990-01-13
# 318630  http://www.billboard.com/charts/hot-100/1990-0... 1990-01-13
# 318227  http://www.billboard.com/charts/hot-100/1990-0... 1990-01-13
# 158287  http://www.billboard.com/charts/hot-100/1990-0... 1990-01-13
# ...                                                   ...        ...
# 19008   https://www.billboard.com/charts/hot-100/2021-... 2021-05-29
# 204390  https://www.billboard.com/charts/hot-100/2021-... 2021-05-29
# 1793    https://www.billboard.com/charts/hot-100/2021-... 2021-05-29
# 224183  https://www.billboard.com/charts/hot-100/2021-... 2021-05-29
# 74511   https://www.billboard.com/charts/hot-100/2021-... 2021-05-29
#
#         Week Position                  Song  \
# 288514             95            Cover Girl
# 90453              15  Two To Make It Right
# 318630             81      Get On Your Feet
# 318227             64      Leave A Light On
# 158287             43       Nothin' To Hide
# ...               ...                   ...
# 19008              67            His & Hers
# 204390             54            Your Power
# 1793               58         Build A Bitch
# 224183             74               Hold On
# 74511              63                   Ski
#
#                                                 Performer  \
# 288514                              New Kids On The Block
# 90453                                           Seduction
# 318630                                     Gloria Estefan
# 318227                                   Belinda Carlisle
# 158287                                               Poco
# ...                                                   ...
# 19008   Internet Money, Don Toliver & Lil Uzi Vert Fea...
# 204390                                      Billie Eilish
# 1793                                         Bella Poarch
# 224183                                      Justin Bieber
# 74511                                  Young Thug & Gunna
#
#                                                    SongID  Instance  \
# 288514                    Cover GirlNew Kids On The Block         1
# 90453                       Two To Make It RightSeduction         1
# 318630                     Get On Your FeetGloria Estefan         1
# 318227                   Leave A Light OnBelinda Carlisle         1
# 158287                                Nothin' To HidePoco         1
# ...                                                   ...       ...
# 19008   His & HersInternet Money, Don Toliver & Lil Uz...         1
# 204390                            Your PowerBillie Eilish         1
# 1793                            Build A BitchBella Poarch         1
# 224183                               Hold OnJustin Bieber         1
# 74511                               SkiYoung Thug & Gunna         1
#
#         Previous Week Position  Peak Position  Weeks on Chart
# 288514                    97.0              2              18
# 90453                     18.0             15              10
# 318630                    80.0             11              16
# 318227                    55.0             11              16
# 158287                    43.0             43               7
# ...                        ...            ...             ...
# 19008                      NaN             67               1
# 204390                    29.0             10               3
# 1793                       NaN             58               1
# 224183                    67.0             20              11
# 74511                     51.0             18               5
#
# [163795 rows x 10 columns]

# %%
shortChart.drop(columns='url')
# Out:
#            WeekID  Week Position                        Song  \
# 8      1997-04-19             97  Don't Keep Wasting My Time
# 9      1997-04-26             90  Don't Keep Wasting My Time
# 10     1997-05-03             97  Don't Keep Wasting My Time
# 11     1997-05-10             97  Don't Keep Wasting My Time
# 12     1997-05-17             93  Don't Keep Wasting My Time
# ...           ...            ...                         ...
# 327873 2018-05-19             21                     Friends
# 327883 1990-07-28             22        I'll Be Your Shelter
# 327886 1998-12-19             22                     I'll Be
# 327890 2018-10-20             22              God Is A Woman
# 327894 2020-11-28             22                       Hawai
#
#                       Performer                                       SongID  \
# 8             Teddy Pendergrass  Don't Keep Wasting My TimeTeddy Pendergrass
# 9             Teddy Pendergrass  Don't Keep Wasting My TimeTeddy Pendergrass
# 10            Teddy Pendergrass  Don't Keep Wasting My TimeTeddy Pendergrass
# 11            Teddy Pendergrass  Don't Keep Wasting My TimeTeddy Pendergrass
# 12            Teddy Pendergrass  Don't Keep Wasting My TimeTeddy Pendergrass
# ...                         ...                                          ...
# 327873  Marshmello & Anne-Marie               FriendsMarshmello & Anne-Marie
# 327883             Taylor Dayne             I'll Be Your ShelterTaylor Dayne
# 327886             Edwin McCain                          I'll BeEdwin McCain
# 327890            Ariana Grande                  God Is A WomanAriana Grande
# 327894      Maluma & The Weeknd                     HawaiMaluma & The Weeknd
#
#         Instance  Previous Week Position  Peak Position  Weeks on Chart
# 8              1                     NaN             97               1
# 9              1                    97.0             90               2
# 10             1                    90.0             90               3
# 11             1                    97.0             90               4
# 12             1                    97.0             90               5
# ...          ...                     ...            ...             ...
# 327873         1                    25.0             21              13
# 327883         1                    12.0              4              13
# 327886         1                    25.0              5              13
# 327890         1                    21.0              8              13
# 327894         1                    12.0             12              13
#
# [163795 rows x 9 columns]

# %%
## series of all weeks the chart published
chartWeeks = sorted(shortChart.WeekID.unique())

print(chartWeeks[len(chartWeeks) - 5:])
# Out:
# [numpy.datetime64('2021-05-01T00:00:00.000000000'), numpy.datetime64('2021-05-08T00:00:00.000000000'), numpy.datetime64('2021-05-15T00:00:00.000000000'), numpy.datetime64('2021-05-22T00:00:00.000000000'), numpy.datetime64('2021-05-29T00:00:00.000000000')]

# %%
## Chart volatility

chartV = []
for week in chartWeeks:
    songsThatWeek = shortChart.loc[shortChart.WeekID == week]
    chartV.append(songsThatWeek['Weeks on Chart'].sum())

volatileTable = pd.DataFrame(columns=['Date', 'ChartVScore'])
volatileTable.Date = chartWeeks
volatileTable.ChartVScore = chartV
volatileTable.head()
# Out:
#         Date  ChartVScore
# 0 1990-01-13         1030
# 1 1990-01-20         1018
# 2 1990-01-27         1012
# 3 1990-02-03          999
# 4 1990-02-10          996

# %%
vix.Date = pd.to_datetime(vix.Date, errors='ignore', infer_datetime_format=True)

# %%
fiveDayAvg = [0, 0, 0, 0]
for i in range(4, vix.shape[0]):
    fiveDayTotal = vix.at[i, 'Close'] + vix.at[i-1, 'Close'] + vix.at[i-2, 'Close'] + vix.at[i-3, 'Close'] + vix.at[i-4, 'Close']
    fiveDayAvg.append(fiveDayTotal / 5)

vix['FiveDayAvg'] = fiveDayAvg
vix.head(10)
# Out:
#         Date       Open       High        Low      Close  Adj Close  Volume  \
# 0 1990-01-03  18.190001  18.190001  18.190001  18.190001  18.190001     0.0
# 1 1990-01-04  19.219999  19.219999  19.219999  19.219999  19.219999     0.0
# 5     20.780001     0.0   22.136000
# ...         ...     ...         ...
# 1633  18.610001     0.0   17.740000
# 1634  16.690001     0.0   18.404000
# 1635  18.809999     0.0   22.206000
# 1636  20.150000     0.0   20.812000
# 1637  16.760000     0.0   17.620000
#
# [1637 rows x 9 columns]

# %%
plt.scatter(volatileTable.FiveDayAvg, volatileTable.ChartVScore, alpha=0.2, c="green")
plt.ylabel("Hot 100 Weekly Volatility Score")
plt.xlabel("VIX 5 Day Average")
plt.title("Hot 100 Volatility as a function of the VIX")
plt.show()

# %%
peakCharts = charts

# %%
peakCharts = peakCharts.sort_values('Peak Position', ascending=True).sort_values('Weeks on Chart', ascending=False).drop_duplicates(['SongID'])

# %%
plt.scatter(peakCharts['Weeks on Chart'], peakCharts['Peak Position'], alpha=0.1)
plt.xlabel("Weeks on Chart")
plt.ylabel("Peak Position (lower is better)")
plt.title("Peak Position as a function of Weeks on Chart")
plt.show()

# %%
peakCharts = peakCharts.drop(['url', 'Instance', 'Previous Week Position'], axis=1)

# %%
peakCharts.shape[0]
# Out:
# 29389

# %%
def urlBuild(song, artist):
    url = "http://www.songlyrics.com/"
    aChunks = artist.replace(' ', '-')
    sChunks = song.split(' ')
    # for ch in aChunks:
        # url = url + ch
        # url = url + '-'
    url = url + aChunks
    url = url + '/'
    for ch in sChunks:
        url = url + ch
        url = url + '-'
    url = url + 'lyrics'
    return url
    
urlBuild("Big Shot", "Kendrick Lamar & Travis Scott")
# Out:
# 'http://www.songlyrics.com/Kendrick-Lamar-&-Travis-Scott/Big-Shot-lyrics'

# %%
testDF = peakCharts.head(20)
for index, row in testDF.iterrows():
    testDF.loc[index, 'lyricLink'] = urlBuild(row.Song, row.Performer)
    print(testDF.loc[index, 'lyricLink'])
# Out:
# http://www.songlyrics.com/Imagine-Dragons/Radioactive-lyrics
# http://www.songlyrics.com/AWOLNATION/Sail-lyrics
# http://www.songlyrics.com/The-Weeknd/Blinding-Lights-lyrics
# http://www.songlyrics.com/Jason-Mraz/I'm-Yours-lyrics
# http://www.songlyrics.com/LeAnn-Rimes/How-Do-I-Live-lyrics
# http://www.songlyrics.com/LMFAO-Featuring-Lauren-Bennett-&-GoonRock/Party-Rock-Anthem-lyrics
# http://www.songlyrics.com/OneRepublic/Counting-Stars-lyrics
# http://www.songlyrics.com/Jewel/Foolish-Games/You-Were-Meant-For-Me-lyrics
# http://www.songlyrics.com/Adele/Rolling-In-The-Deep-lyrics
# http://www.songlyrics.com/Carrie-Underwood/Before-He-Cheats-lyrics
# http://www.songlyrics.com/Lifehouse/You-And-Me-lyrics
# http://www.songlyrics.com/The-Lumineers/Ho-Hey-lyrics
# http://www.songlyrics.com/Gabby-Barrett-Featuring-Charlie-Puth/I-Hope-lyrics
# http://www.songlyrics.com/Imagine-Dragons/Demons-lyrics
# http://www.songlyrics.com/Post-Malone/Circles-lyrics
# http://www.songlyrics.com/Lady-Antebellum/Need-You-Now-lyrics
# http://www.songlyrics.com/Los-Del-Rio/Macarena-(Bayside-Boys-Mix)-lyrics
# http://www.songlyrics.com/John-Legend/All-Of-Me-lyrics
# http://www.songlyrics.com/Gotye-Featuring-Kimbra/Somebody-That-I-Used-To-Know-lyrics
# http://www.songlyrics.com/The-Fray/How-To-Save-A-Life-lyrics

# %%
from bs4 import BeautifulSoup
import requests

failureStr = "error, no lyrics found"
def webGrab(url):
    html = requests.get(url, allow_redirects=True).text
    soup = BeautifulSoup(html, 'html5lib')
    try:
        lyrics = soup.find(id="songLyricsDiv").text
    except:
        return failureStr
    lyrics = lyrics.replace('\n', ' ')
    lyrics = lyrics.replace(',', '')
    lyrics = lyrics.replace('-', ' ')
    lyrics = lyrics.replace('!', '')
    lyrics = lyrics.replace('(', '')
    lyrics = lyrics.replace(')', '')
    lyrics = lyrics.replace('?', '')
    lyrics = lyrics.lower()
    return lyrics

# %%
## BUILD URLS
lyricCharts = peakCharts
print(lyricCharts.shape[0])
lyricCharts['lyricLink'] = ""
lyricCharts['lyrics'] = ""

for index, row in lyricCharts.iterrows():
    lyricCharts.loc[index, 'lyricLink'] = urlBuild(row.Song, row.Performer)
# Out:
# 29389

# %%
lyricCharts.head()
# Out:
#            WeekID  Week Position             Song        Performer  \
# 302681 2014-05-10             49      Radioactive  Imagine Dragons
# 302673 2014-03-22             45             Sail       AWOLNATION
# 302665 2021-05-29             23  Blinding Lights       The Weeknd
# 278572 2009-10-10             48        I'm Yours       Jason Mraz
# 278565 1998-10-10             45    How Do I Live      LeAnn Rimes
#
#                             SongID  Peak Position  Weeks on Chart  \
# 302681  RadioactiveImagine Dragons              3              87
# 302673              SailAWOLNATION             17              79
# 302665   Blinding LightsThe Weeknd              3              76
# 278572         I'm YoursJason Mraz              6              76
# 278565    How Do I LiveLeAnn Rimes              2              69
#
#                                                 lyricLink  \
# 302681  http://www.songlyrics.com/Imagine-Dragons/Radi...
# 302673   http://www.songlyrics.com/AWOLNATION/Sail-lyrics
# 302665  http://www.songlyrics.com/The-Weeknd/Blinding-...
# 278572  http://www.songlyrics.com/Jason-Mraz/I'm-Yours...
# 278565  http://www.songlyrics.com/LeAnn-Rimes/How-Do-I...
#
#                                                    lyrics
# 302681                                   No found records
# 302673                                   No found records
# 302665  sorry we have no the weeknd   blinding lights ...
# 278572                                   No found records
# 278565                                   No found records

# %%
count = 0
for index, row in lyricCharts.iterrows():
    lyricCharts.loc[index, 'lyrics'] = webGrab(lyricCharts.loc[index, 'lyricLink'])
    count = count + 1
    print(count/lyricCharts.shape[0] * 100 + "%")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-b08b004f29f6> in <module>
#       1 count = 0
#       2 for index, row in lyricCharts.iterrows():
# ----> 3     lyricCharts.loc[index, 'lyrics'] = webGrab(lyricCharts.loc[index, 'lyricLink'])
#       4     count = count + 1
#       5     print(count/lyricCharts.shape[0] * 100 + "%")
#
# <ipython-input-64-9b34e0a6b4dd> in webGrab(url)
#       5     html = requests.get(url, allow_redirects=False).text
#       6     soup = BeautifulSoup(html, 'html5lib')
# ----> 7     lyrics = soup.find('p', id="songLyricsDiv").text
#       8     # except:
#       9         # return "No found records"
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
webGrab("http://www.songlyrics.com/imagine-dragons/radioactive-lyrics/")
# Out:
# "i'm waking up to ash and dust i wipe my brow and i sweat my rust i'm breathing in the chemicals  i'm breaking in and shaping up then checking out on the prison bus this is it the apocalypse whoa  i'm waking up i feel it in my bones enough to make my system blow welcome to the new age to the new age welcome to the new age to the new age  whoa oh oh oh oh whoa oh oh oh i'm radioactive radioactive  whoa oh oh oh oh whoa oh oh oh i'm radioactive radioactive  i raise my flag and dye my clothes it's a revolution i suppose we're painted red to fit right in whoa  i'm breaking in and shaping up then checking out on the prison bus this is it the apocalypse whoa  i'm waking up i feel it in my bones enough to make my system blow welcome to the new age to the new age welcome to the new age to the new age  whoa oh oh oh oh whoa oh oh oh i'm radioactive radioactive  whoa oh oh oh oh whoa oh oh oh i'm radioactive radioactive  all systems go the sun hasn't died deep in my bones straight from inside  i'm waking up i feel it in my bones enough to make my system blow welcome to the new age to the new age welcome to the new age to the new age  whoa oh oh oh oh whoa oh oh oh i'm radioactive radioactive  whoa oh oh oh oh whoa oh oh oh i'm radioactive radioactive"

# %%
## TEST DF WEBGRAB
count = 0
for index, row in testDF.iterrows():
    testDF.loc[index, 'lyrics'] = webGrab(testDF.loc[index, 'lyricLink'])
    count = count + 1
    print(testDF.loc[index, 'lyrics'])
    print()

# %%
testDF.head()
# Out:
#            WeekID  Week Position             Song        Performer  \
# 302681 2014-05-10             49      Radioactive  Imagine Dragons
# 302673 2014-03-22             45             Sail       AWOLNATION
# 302665 2021-05-29             23  Blinding Lights       The Weeknd
# 278572 2009-10-10             48        I'm Yours       Jason Mraz
# 278565 1998-10-10             45    How Do I Live      LeAnn Rimes
#
#                             SongID  Peak Position  Weeks on Chart  \
# 302681  RadioactiveImagine Dragons              3              87
# 302673              SailAWOLNATION             17              79
# 302665   Blinding LightsThe Weeknd              3              76
# 278572         I'm YoursJason Mraz              6              76
# 278565    How Do I LiveLeAnn Rimes              2              69
#
#                                                 lyricLink  \
# 302681  http://www.songlyrics.com/Imagine-Dragons-/Rad...
# 302673  http://www.songlyrics.com/AWOLNATION-/Sail-lyrics
# 302665  http://www.songlyrics.com/The-Weeknd-/Blinding...
# 278572  http://www.songlyrics.com/Jason-Mraz-/I'm-Your...
# 278565  http://www.songlyrics.com/LeAnn-Rimes-/How-Do-...
#
#                                                    lyrics
# 302681                                   No found records
# 302673                                   No found records
# 302665  sorry we have no the weeknd   blinding lights ...
# 278572                                   No found records
# 278565                                   No found records

# %%
lyricCharts.sample(10)
# Out:
#            WeekID  Week Position  \
# 65691  1968-11-16             85
# 18549  2020-03-28             62
# 173883 1976-10-30             65
# 232747 1974-02-09             97
# 240068 1978-04-15             94
# 232735 1992-06-20             97
# 230712 1975-11-08             46
# 132347 2001-09-29            100
# 62955  1969-11-22             75
# 131845 1964-08-01             46
#
#                                                      Song  \
# 65691                         Aunt Dora's Love Soul Shack
# 18549                                         Moon Relate
# 173883                                Don't Think....Feel
# 232747                                          Flashback
# 240068  Mammas Don't Let Your Babies Grow Up To Be Cow...
# 232735                           Love You All My Lifetime
# 230712                       Every Day I Have To Cry Some
# 132347                                         What It Is
# 62955                                       See Ruby Fall
# 131845                          What Have I Got Of My Own
#
#                               Performer  \
# 65691                     Arthur Conley
# 18549                      Lil Uzi Vert
# 173883                     Neil Diamond
# 232747                The 5th Dimension
# 240068                  Waylon & Willie
# 232735                       Chaka Khan
# 230712                 Arthur Alexander
# 132347  Violator Featuring Busta Rhymes
# 62955                       Johnny Cash
# 131845                      Trini Lopez
#
#                                                    SongID  Peak Position  \
# 65691            Aunt Dora's Love Soul ShackArthur Conley             85
# 18549                             Moon RelateLil Uzi Vert             62
# 173883                    Don't Think....FeelNeil Diamond             43
# 232747                         FlashbackThe 5th Dimension             82
# 240068  Mammas Don't Let Your Babies Grow Up To Be Cow...             42
# 232735                 Love You All My LifetimeChaka Khan             68
# 230712       Every Day I Have To Cry SomeArthur Alexander             45
# 132347          What It IsViolator Featuring Busta Rhymes             63
# 62955                            See Ruby FallJohnny Cash             75
# 131845               What Have I Got Of My OwnTrini Lopez             43
#
#         Weeks on Chart                                          lyricLink  \
# 65691                4  http://www.songlyrics.com/Arthur-Conley-/Aunt-...
# 18549                1  http://www.songlyrics.com/Lil-Uzi-Vert-/Moon-R...
# 173883               8  http://www.songlyrics.com/Neil-Diamond-/Don't-...
# 232747               9  http://www.songlyrics.com/The-5th-Dimension-/F...
# 240068              10  http://www.songlyrics.com/Waylon-&-Willie-/Mam...
# 232735               9  http://www.songlyrics.com/Chaka-Khan-/Love-You...
# 230712               9  http://www.songlyrics.com/Arthur-Alexander-/Ev...
# 132347              14  http://www.songlyrics.com/Violator-Featuring-B...
# 62955                3  http://www.songlyrics.com/Johnny-Cash-/See-Rub...
# 131845              13  http://www.songlyrics.com/Trini-Lopez-/What-Ha...
#
#                                                    lyrics
# 65691                                    No found records
# 18549   sorry we have no lil uzi vert   moon relate ly...
# 173883                                   No found records
# 232747                                   No found records
# 240068                                   No found records
# 232735                                   No found records
# 230712                                   No found records
# 132347  sorry we have no violator featuring busta rhym...
# 62955                                    No found records
# 131845                                   No found records

# %%
lyricCharts.to_csv('scrape1.csv')

# %%
count = 0
for index, row in lyricCharts.iterrows():
    temp = lyricCharts.loc[index, 'lyrics']
    if 'No found records' in temp or 'sorry we have no' in temp:
        count = count + 1

print(count/lyricCharts.shape[0])
# Out:
# 1.0

# %%
lyricCharts.shape[0]
# Out:
# 29389

# %%
## TEST DF WEBGRAB
from IPython.display import clear_output
count = 0
failCount = 0
total = lyricCharts.shape[0]
redirectE = "Redirect error"

for index, row in lyricCharts.iterrows():
    count = count + 1
    try: 
        lyricCharts.loc[index, 'lyrics'] = webGrab(lyricCharts.loc[index, 'lyricLink'])
    except:
        lyricCharts.loc[index, 'lyricBool'] = False
        failCount = failCount + 1
        lyricCharts.loc[index, 'lyrics'] = redirectE
        print("Caught an error")
        print("failure number: ", failCount)
        continue
    if failureStr in lyricCharts.loc[index, 'lyrics'] or "sorry we have no" in lyricCharts.loc[index, 'lyrics']:
        failCount = failCount + 1
        lyricCharts.loc[index, 'lyricBool'] = False
        clear_output(wait=True)
        print("failure number: ", failCount)
    else:
        clear_output(wait=True)
        print("success")
        lyricCharts.loc[index, 'lyricBool'] = True
    print("total done: ", count)
    print("progress: ", count / total)
# Out:
# success
# total done:  29389
# progress:  1.0

# %%
lyricCharts.to_csv('scrape2.csv')

# %%
print("success rate: ", (total - failCount)/total)
# Out:
# success rate:  0.7016911089183028

# %%
testCount = lyricCharts.sample(10)

# %%
testCount.head()
# Out:
#            WeekID  Week Position                            Song  \
# 261966 1960-05-07             84     (There Was A) Tall Oak Tree
# 297741 1999-01-23             95                   Big Big World
# 90318  1987-02-07             99                      Two People
# 189159 1963-04-27             50       All I Have To Do Is Dream
# 66997  1970-05-30             58  The Onion Song/California Soul
#
#                           Performer  \
# 261966              Dorsey Burnette
# 297741                       Emilia
# 90318                   Tina Turner
# 189159          Richard Chamberlain
# 66997   Marvin Gaye & Tammi Terrell
#
#                                                    SongID  Peak Position  \
# 261966         (There Was A) Tall Oak TreeDorsey Burnette             23
# 297741                                Big Big WorldEmilia             95
# 90318                               Two PeopleTina Turner             30
# 189159       All I Have To Do Is DreamRichard Chamberlain             14
# 66997   The Onion Song/California SoulMarvin Gaye & Ta...             50
#
#         Weeks on Chart                                          lyricLink  \
# 261966              15  http://www.songlyrics.com/Dorsey-Burnette/(The...
# 297741               2  http://www.songlyrics.com/Emilia/Big-Big-World...
# 90318               12  http://www.songlyrics.com/Tina-Turner/Two-Peop...
# 189159              12  http://www.songlyrics.com/Richard-Chamberlain/...
# 66997                7  http://www.songlyrics.com/Marvin-Gaye-&-Tammi-...
#
#                                                    lyrics lyricBool
# 261966  there was a tall oak tree dorsey burnette  the...      True
# 297741  i'm a big big girl in a big big world it's not...      True
# 90318   two people living on the edge of life are peop...      True
# 189159  we do not have the lyrics for all i have to do...      True
# 66997                              error, no lyrics found     False

# %%
songsWithLyrics = lyricCharts.loc[lyricCharts.lyricBool == True]

# %%
## Count most common words
songCount = {}

for row in songsWithLyrics.lyrics:
    temp = row.split(' ')
    for word in temp: 
        if word not in songCount:
            songCount[word] = 1
        else:
            songCount[word] = songCount[word] + 1

sortedCounts = dict(sorted(songCount.items(), key= lambda x:x[1], reverse=True))
print(sortedCounts)
# Out:
# {'': 214146, 'you': 211434, 'i': 198497, 'the': 183777, 'to': 119939, 'and': 116479, 'a': 106934, 'me': 101539, 'it': 77230, 'my': 76434, 'in': 64087, 'love': 54589, 'on': 54548, 'that': 52589, 'your': 51002, "i'm": 49235, 'of': 47108, 'be': 42599, 'all': 40071, "don't": 39693, 'know': 36682, 'for': 36598, 'oh': 35418, 'so': 34859, 'is': 33769, 'we': 33746, 'just': 32825, 'like': 32074, 'do': 31758, 'baby': 31111, 'but': 30506, 'no': 29596, "it's": 28713, 'with': 28665, 'when': 27717, 'up': 27298, 'got': 26798, 'yeah': 26584, 'can': 25552, 'what': 25536, 'get': 25039, 'now': 24296, 'this': 23874, 'if': 22755, "you're": 21594, 'go': 20659, 'one': 19413, 'out
'lonely': 3199, 'big': 3185, 'dream': 3153, 'place': 3122, 'feeling': 3116, 'fall': 3088, "we'll": 3051, 'uh': 3036, 'enough': 3029, 'other': 3025, 'care': 3010, 'touch': 2988, 'woman': 2984, "'em": 2983, 'forever': 2981, 'girls': 2918, 'free': 2915, 'change': 2913, 'maybe': 2907, 'thought': 2903, 'song': 2896, 'sun': 2866, "what's": 2844, 'alright': 2830, 'remember': 2830, 'move': 2826, 'has': 2805, 'while': 2792, 'best': 2787, 'soul': 2782, 'stand': 2769, 'bring': 2756, 'rain': 2752, 'whoa': 2750, 'somebody': 2750, 'side': 2748, 'start': 2730, 'shake': 2728, '/>': 2703, 'found': 2698, 'told': 2693, 'myself': 2685, 'nigga': 2682, 'wait': 2678, 'knew': 2676, ...

# %%
def extraClean(song):
    song = song.replace('/>', '')
    song = song.replace('<br', ' ')
    
    return song

# %%
for index, row in songsWithLyrics.iterrows():
    lyricCharts.loc[index, 'lyrics'] = extraClean(lyricCharts.loc[index, 'lyrics'])

# %%
import json

with open("totalCount", "w") as file:
    json.dump(sortedCounts, file)

# %%
## Count most common words with no duplicates
songCount = {}

for row in songsWithLyrics.lyrics:
    temp = row.split(' ')
    
    dupList = list(set(temp))
    for word in dupList: 
        if word not in songCount:
            songCount[word] = 1
        else:
            songCount[word] = songCount[word] + 1

sortedCounts = dict(sorted(songCount.items(), key= lambda x:x[1], reverse=True))
print(sortedCounts)
# Out:
# {'the': 19360, '': 18659, 'to': 17956, 'and': 17915, 'i': 17557, 'you': 17522, 'a': 16602, 'me': 15493, 'in': 14896, 'my': 14330, 'that': 13626, 'it': 13517, 'of': 13147, 'on': 12505, 'for': 12060, 'all': 12022, 'your': 11901, 'be': 11564, 'so': 11304, 'but': 11219, 'just': 10854, 'know': 10847, "i'm": 10790, 'love': 10695, 'is': 10505, "don't": 10027, 'when': 9804, 'with': 9731, 'do': 9204, "it's": 9022, 'like': 8999, 'we': 8827, 'what': 8533, 'no': 8504, 'can': 8490, 'now': 8348, 'this': 8057, 'up': 8043, 'if': 7850, 'oh': 7791, 'got': 7784, 'have': 7552, 'out': 7366, 'time': 7292, 'one': 7114, 'see': 6995, 'go': 6976, 'get': 6923, "you're": 6816, 'down': 6698, 'never': 6543, 'not': 6537, "can't": 6453, 'say': 6441, 'baby': 6416, 'way': 6197, 'make': 6138, 'was': 6002, 'yeah': 5998, 'come': 5991, 'at': 5829, 'from': 5660, 'are': 5598, 'take': 5512, 'want': 5489, 'let': 5386, 'right': 5327, 'how': 5290, "i'll": 5197, 'there': 5056, 'heart': 5002, 'back': 4996, 'they': 4989, 'will': 4842, 'feel': 4840, 'tell': 4798, 'night': 4736, 'been': 4597, "i've": 4541, 'by': 4499, 'gonna': 4498, 'need': 4494, 'could': 4451, "'cause": 4446, 'as': 4439, 'here': 4430, 'day': 4374, 'girl': 4229, 'away': 4228, "that's": 4220, 'then': 4217, 'life': 4216, 'more': 4062, 'too': 3958, 'about': 3907, "there's": 3873, 'wanna': 3857, 'think': 3855, 'through': 3848